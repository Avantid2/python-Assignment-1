# %% [markdown]
# # Q1 write a python program to calculate the length of string

# %%
S=input("Enter the string")
# Out:
# Enter the stringToday is first day of new year

# %%
print(S)
# Out:
# Today is first day of new year

# %% [markdown]
# # Length is string

# %%
l1=len(S)

# %%
print("length of the string:",l1)
# Out:
# length of the string: 30

# %% [markdown]
# # Q2 Python program to calculate the square root.

# %%
import math

# %%
print("square root of 16 is",math.sqrt(16))#pass the decimal number
# Out:
# square root of 16 is 4.0

# %% [markdown]
# # Q3 Write a python program to convert temperature in Celcius to temperature in Fahrenheit.

# %%
Celcius=30

# %%
Fahrenheit=Celcius*9/5+32

# %%
print(Fahrenheit)
# Out:
# 86.0

# %% [markdown]
# # Q4 Write a data type needed for given data.(10,4.5,2+6j)

# %%
num=10

# %%
type(10)
# Out:
# int

# %%
num1=4.5

# %%
type(num1)
# Out:
# float

# %%
num2=2+6j

# %%
type(num2)
# Out:
# complex
